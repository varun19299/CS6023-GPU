# %% [markdown]
# # Assignment 1
#
# ## Plots
#
# ### Question 2

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
fig = plt.figure(figsize=(10, 10))
dpi=fig.dpi

# %%
clock=5505000 ## kHz
clock=clock/10**6 # Ghz
peak_flops=3584*clock*2 ## TFLOPS
peak_flops=11.3
print(peak_flops)
peak_band=0.484440000 ## GB/s
x=peak_flops/peak_band
tt=np.logspace(-3,6,200,base=2)

ii=np.argmin(np.abs(tt*peak_band-peak_flops))
print(x)
print(tt*peak_band)
print(peak_flops)
# Out:
# 11.3
# 23.32590207249608
# [  0.060555     0.06248337   0.06447314   0.06652629   0.06864481
#    0.0708308    0.07308639   0.07541382   0.07781537   0.08029339
#    0.08285033   0.08548869   0.08821107   0.09102014   0.09391867
#    0.0969095    0.09999557   0.10317992   0.10646567   0.10985606
#    0.11335442   0.11696418   0.12068889   0.12453221   0.12849793
#    0.13258993   0.13681225   0.14116902   0.14566453   0.15030321
#    0.1550896    0.16002841   0.1651245    0.17038287   0.1758087
#    0.18140731   0.1871842    0.19314507   0.19929575   0.2056423
#    0.21219096   0.21894816   0.22592055   0.23311496   0.24053849
#    0.24819841   0.25610226   0.26425781   0.27267308   0.28135632
#    0.29031609   0.29956118   0.30910067   0.31894395   0.32910069
#    0.33958087   0.35039479   0.36155307   0.37306669   0.38494697
#    0.39720556   0.40985454   0.42290631   0.43637372   0.45027      0.4646088
#    0.47940422   0.4946708    0.51042354   0.52667793   0.54344994
#    0.56075605   0.57861327   0.59703915   0.6160518    0.63566991
#    0.65591275   0.67680023   0.69835286   0.72059184   0.74353901
#    0.76721694   0.79164889   0.81685887   0.84287166   0.86971282
#    0.89740874   0.92598663   0.95547458   0.98590157   1.01729751
#    1.04969325   1.08312062   1.11761249   1.15320275   1.18992637
#    1.22781946   1.26691925   1.30726416   1.34889386   1.39184925
#    1.43617255   1.48190732   1.52909851   1.5777925    1.62803715
#    1.67988183   1.73337749   1.78857673   1.84553377   1.90430461
#    1.964947     2.02752054   2.09208673   2.15870902   2.2274529
#    2.29838591   2.37157778   2.44710044   2.5250281    2.60543737
#    2.68840726   2.77401932   2.86235769   2.95350919   3.04756339
#    3.14461274   3.24475262   3.34808144   3.45470076   3.56471536
#    3.67823336   3.79536634   3.9162294    4.04094133   4.1696247
#    4.30240598   4.43941567   4.58078842   4.72666317   4.87718328
#    5.0324967    5.19275605   5.35811885   5.5287476    5.70481002
#    5.88647912   6.07393346   6.26735726   6.46694063   6.6728797
#    6.88537689   7.10464103   7.33088761   7.56433899   7.80522461
#    8.05378121   8.31025306   8.57489224   8.84795882   9.12972119
#    9.42045624   9.72044973  10.02999648  10.34940071  10.67897634
#   11.01904727  11.36994773  11.73202258  12.10562766  12.49113016
#   12.88890895  13.29935497  13.7228716   14.15987507  14.61079487
#   15.07607417  15.55617024  16.05155493  16.56271509  17.09015309
#   17.6343873   18.1959526   18.77540089  19.37330165  19.9902425
#   20.62682978  21.2836891   21.96146605  22.66082674  23.3824585
#   24.12707055  24.8953947   25.68818605  26.50622376  27.3503118
#   28.22127974  29.11998357  30.04730653  31.00416   ]
# 11.3

# %%
## Bandwith line
plt.plot(tt[:ii+1],peak_band*tt[:ii+1],'r');
plt.plot(tt[ii:],peak_flops*np.ones_like(tt)[ii:],'b');
plt.xlabel("Ops per Byte; Performance")
plt.ylabel("Ops per cycle; Op intensity")
plt.axis([0,60,0,12])
plt.show()
plt.savefig("q2.jpg")

# %% [markdown]
# ### Question 4

# %%
tt=[0.312521,0.305454, 0.306201, 0.305753, 0.305040, 0.304541]
xx=[32,64,128,256,512,1024]
plt.plot(xx,tt,'r')
plt.xscale
plt.xlabel("Number of threads/block")
plt.ylabel("Avergae time for 10 runs")
plt.axis([30,1024,0.3,0.313])
plt.show()

# %% [markdown]
# ## Question 5

# %%
tt=[0.298492, 0.349331 ,0.296480, 0.340138, 0.374680, 0.454981, 0.570481, 0.864831]
xx=[2**x for x in range(1,9)]
plt.plot(xx,tt,'r')
plt.xscale('log')
plt.xlabel("Number of ops/thread")
plt.ylabel("Avergae time for 10 runs")
plt.axis([0,130,0.2,0.6])
plt.show()
# Out:
# /Users/Ankivarun/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2923: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '

# %% [markdown]
# ## Question 6

# %%
tt=[0.298492, 0.349331 ,0.296480, 0.340138, 0.374680, 0.454981, 0.570481, 0.864831]
xx=[2**x for x in range(1,9)]
plt.plot(xx,tt,'r')
plt.xscale('log')
plt.xlabel("Vector size")
plt.ylabel("Avergae time for 10 runs")
plt.axis([0,130,0.2,0.6])
plt.show()
